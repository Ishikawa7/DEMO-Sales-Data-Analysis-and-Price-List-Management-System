# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data_raw/dbo_ART_COSTI.xlsx')
df
# Out:
#              COD_ART COD_TIPO_COST   COD_ART_TIPO_COST  COSTO_ART   DATA_RIF  \
# 0     017.GUI.MED.01           ATT  017.GUI.MED.01\ATT       0.35 2022-03-09
# 1          017.PM001           ATT       017.PM001\ATT       1.00 2023-08-28
# 2          017.PM001           ATT       017.PM001\ATT       1.00 2023-08-28
# 3          017.PM001           ATT       017.PM001\ATT       1.00 2023-08-28
# 4          017.PM001           ATT       017.PM001\ATT       1.00 2023-08-28
# ...              ...           ...                 ...        ...        ...
# 2736  098.P055CF6ANT           ATT  098.P055CF6ANT\ATT       3.50 2015-09-08
# 2737  098.P055CF6ANT           ATT  098.P055CF6ANT\ATT       3.50 2013-05-02
# 2738       0MAG.0001           ATT       0MAG.0001\ATT      80.00 2018-06-14
# 2739       0MAG.0002           ATT       0MAG.0002\ATT      60.00 2018-06-14
# 2740         COM.ACC           ATT         COM.ACC\ATT       0.88 2021-05-11
#
# ...

# %%
df.columns
# Out:
# Index(['COD_ART', 'COD_TIPO_COST', 'COD_ART_TIPO_COST', 'COSTO_ART',
#        'DATA_RIF', 'COD_ART_VAR_TIPO_COSTO_STDAG', 'COD_VAR', 'COD_ART_VAR',
#        'AZIENDA_ID', 'COD_ART_VAR_TIPO_COS_AZ_STDAG'],
#       dtype='object')

# %%
df = df.drop(columns=['COD_ART_TIPO_COST','COD_ART_VAR', 'COD_ART_VAR_TIPO_COSTO_STDAG', 'COD_ART_VAR_TIPO_COS_AZ_STDAG'])
df
# Out:
#              COD_ART COD_TIPO_COST  COSTO_ART   DATA_RIF  COD_VAR  AZIENDA_ID
# 0     017.GUI.MED.01           ATT       0.35 2022-03-09      NaN           1
# 1          017.PM001           ATT       1.00 2023-08-28      2.0           1
# 2          017.PM001           ATT       1.00 2023-08-28      3.0           1
# 3          017.PM001           ATT       1.00 2023-08-28      4.0           1
# 4          017.PM001           ATT       1.00 2023-08-28      5.0           1
# ...              ...           ...        ...        ...      ...         ...
# 2736  098.P055CF6ANT           ATT       3.50 2015-09-08      1.0           1
# 2737  098.P055CF6ANT           ATT       3.50 2013-05-02      NaN           1
# 2738       0MAG.0001           ATT      80.00 2018-06-14      NaN           1
# 2739       0MAG.0002           ATT      60.00 2018-06-14      NaN           1
# 2740         COM.ACC           ATT       0.88 2021-05-11      NaN           1
#
# [2741 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['COD_ART', 'COD_TIPO_COST', 'COSTO_ART', 'DATA_RIF', 'COD_VAR',
#        'AZIENDA_ID'],
#       dtype='object')

# %%
df = df[['COD_ART','COD_VAR','COD_TIPO_COST','COSTO_ART','DATA_RIF','AZIENDA_ID']]
df['COD_VAR'] = df['COD_VAR'].fillna(0).astype(int)
df
# Out:
#              COD_ART  COD_VAR COD_TIPO_COST  COSTO_ART   DATA_RIF  AZIENDA_ID
# 0     017.GUI.MED.01        0           ATT       0.35 2022-03-09           1
# 1          017.PM001        2           ATT       1.00 2023-08-28           1
# 2          017.PM001        3           ATT       1.00 2023-08-28           1
# 3          017.PM001        4           ATT       1.00 2023-08-28           1
# 4          017.PM001        5           ATT       1.00 2023-08-28           1
# ...              ...      ...           ...        ...        ...         ...
# 2736  098.P055CF6ANT        1           ATT       3.50 2015-09-08           1
# 2737  098.P055CF6ANT        0           ATT       3.50 2013-05-02           1
# 2738       0MAG.0001        0           ATT      80.00 2018-06-14           1
# 2739       0MAG.0002        0           ATT      60.00 2018-06-14           1
# 2740         COM.ACC        0           ATT       0.88 2021-05-11           1
#
# [2741 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2741 entries, 0 to 2740
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   COD_ART        2741 non-null   object
#  1   COD_VAR        2741 non-null   int64
#  2   COD_TIPO_COST  2741 non-null   object
#  3   COSTO_ART      2741 non-null   float64
#  4   DATA_RIF       2741 non-null   datetime64[ns]
#  5   AZIENDA_ID     2741 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 128.6+ KB

# %%
df.to_csv('data_clean/art_costi.csv', index=False)
