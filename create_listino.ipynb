# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data_raw/Aggiornamento_ART_COSTI_per_tipo_articoli_21-08_2023.xlsx', sheet_name='art_costi_veneziane')
df
# Out:
#    COD_ART_VAR_TIPO_COS_AZ_STDAG       COD_ART COD_ART_TIPO_COST  COSTO_ART  \
# 0         017.PM419\000001\ATT\1     017.PM419               ATT      46.52
# 1         017.PM420\000001\ATT\1     017.PM420               ATT      46.52
# 2         017.PM421\000001\ATT\1     017.PM421               ATT      48.75
# 3         017.PM422\000003\ATT\1     017.PM422               ATT      46.52
# 4         017.PM423\000001\ATT\1     017.PM423               ATT      46.52
# 5         017.PM424\000002\ATT\1     017.PM424               ATT      51.80
# 6         017.PM425\000001\ATT\1     017.PM425               ATT      46.52
# 7         017.PM426\000001\ATT\1     017.PM426               ATT      61.82
# 8         017.PM427\000001\ATT\1     017.PM427               ATT      46.52
# 9         017.PM429\000001\ATT\1     017.PM429               ATT      46.52
# 10        017.PM430\000001\ATT\1     017.PM430               ATT      63.02
# ...
