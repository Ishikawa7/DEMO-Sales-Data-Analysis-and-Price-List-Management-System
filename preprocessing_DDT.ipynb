# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data_raw/dbo_DDT_FOR_RIGHE.xlsx')
df
# Out:
#        AZIENDA_ID              DOC_ID  NUM_RIGA             DOC_RIGA_ID  \
# 0               1  2016-BADDV-0000001         1  2016-BADDV-0000001-001
# 1               1  2016-BADDV-0000001         2  2016-BADDV-0000001-002
# 2               1  2016-BADDV-0000001         3  2016-BADDV-0000001-003
# 3               1  2016-BADDV-0000001         4  2016-BADDV-0000001-004
# 4               1  2016-BADDV-0000001         5  2016-BADDV-0000001-005
# ...           ...                 ...       ...                     ...
# 33357           1  2024-BADDV-0000447        17  2024-BADDV-0000447-017
# 33358           1  2024-BADDV-0000447        18  2024-BADDV-0000447-018
# 33359           1  2024-BADDV-0000448         1  2024-BADDV-0000448-001
# 33360           1  2024-BADDV-0000448         2  2024-BADDV-0000448-002
# 33361           1  2024-BADDV-0000449         1  2024-BADDV-0000449-001
#
#        COD_CF UM_BASE                 COD_ART  \
# 0        2521      PZ           017.PM107.001
# ...

# %%
df.columns
# Out:
# Index(['AZIENDA_ID', 'DOC_ID', 'NUM_RIGA', 'DOC_RIGA_ID', 'COD_CF', 'UM_BASE',
#        'COD_ART', 'DES_RIGA', 'DATA_DOC', 'UM', 'QUANT_RIGA', 'QUANT_UM_BASE',
#        'PREZZO_NETTO_VU1', 'PREZZO_NETTO_TOT_VU1', 'IMPORTO_V1',
#        'IMPORTO_PAG_V1', 'PREZZO_LORDO_VU1', 'PREZZO_NETTO_PAG_VU1', 'COD_VAR',
#        'COD_ART_VAR', 'NUM_UM', 'UM_CONFEZIONE', 'NUMERO_CONFEZIONI',
#        'CONT_1_CONFEZIONE', 'PREZZO_LORDO_VU2', 'SCONTO_1', 'SCONTO_2',
#        'SCONTO_3', 'SCONTO_4', 'SCONTO_5', 'SCONTO_6', 'SCONTO_7',
#        'SCONTO_CALCOLATO', 'SCONTO_PAG', 'PREZZO_NETTO_VU2', 'IMPORTO_V2',
#        'PREZZO_NETTO_PAG_VU2', 'IMPORTO_PAG_V2', 'NOTE', 'NOTE_INT', 'COD_IVA',
#        'COD_CONTO', 'CONVERS_UM_BASE', 'FLAG_OMAGGIO', 'FLAG_MOV_MAGAZZ_2',
#        'FLAG_NO_CESSIONE', 'COD_CAUS_MAG', 'COD_DEP', 'COD_DEP_2',
#        'FLAG_NO_STAMPA', 'NUM_SOTTORIGA', 'COD_CAT', 'FLAG_CONVERS_EDITABILE',
#        'PESO', 'DES_RIGA_L2', 'PESO_NETTO', 'PESO_IMBALLO', 'COSTI_RIGA_V1',
# ...

# %%
df.drop(columns=['DOC_RIGA_ID','COD_ART_VAR',"NUM_UM",'SCONTO_1', 'SCONTO_2',
       'SCONTO_3', 'SCONTO_4', 'SCONTO_5', 'SCONTO_6', 'SCONTO_7',
       'SCONTO_CALCOLATO', 'SCONTO_PAG',])
